# %%
import requests

from config import weather_api_key

import time

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the random module.
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
coordinates = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ff94065ca6d745f5526d5e039874437d

# %%
# Import the datetime module from the datetime library
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

 
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    time.sleep(1)

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | touros
# Processing Record 2 of Set 1 | haines junction
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | tolmachevo
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | maragogi
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | tingi
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | grand forks
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | altadena
# Processing Record 18 of Set 1 | rawson
# Processing Record 19 of Set 1 | shuangcheng
# Processing Record 20 of Set 1 | muros
# Processing Record 21 of Set 1 | juneau
# Processing Record 22 of Set 1 | omboue
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | taggia
# Processing Record 25 of Set 1 | muisne
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | sakakah
# Processing Record 28 of Set 1 | constitucion
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | gushikawa
# Processing Record 32 of Set 1 | bereda
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | yeniseysk
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | carutapera
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | san cristobal
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 1 | kupang
# Processing Record 45 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 1 | lubango
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | koumac
# Processing Record 1 of Set 2 | turukhansk
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | vestmannaeyjar
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | luderitz
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | bintulu
# Processing Record 11 of Set 2 | basco
# Processing Record 12 of Set 2 | marzuq
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | ust-barguzin
# Processing Record 16 of Set 2 | shingu
# Processing Record 17 of Set 2 | malindi
# Processing Record 18 of Set 2 | ewa beach
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | esperance
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | mount isa
# Processing Record 24 of Set 2 | ostrovnoy
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | nome
# Processing Record 27 of Set 2 | le port
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | ust-nera
# Processing Record 30 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 2 | henties bay
# Processing Record 32 of Set 2 | borogontsy
# Processing Record 33 of Set 2 | pljevlja
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | dunedin
# Processing Record 36 of Set 2 | sao geraldo do araguaia
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | lensk
# Processing Record 39 of Set 2 | ambovombe
# Processing Record 40 of Set 2 | san rafael
# Processing Record 41 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 2 | hami
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 2 | manokwari
# Processing Record 46 of Set 2 | alofi
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | naze
# Processing Record 50 of Set 2 | pilao arcado
# City not found. Skipping...
# Processing Record 1 of Set 3 | karratha
# Processing Record 2 of Set 3 | ahipara
# Processing Record 3 of Set 3 | chipiona
# Processing Record 4 of Set 3 | namibe
# Processing Record 5 of Set 3 | balloch
# Processing Record 6 of Set 3 | bengkulu
# Processing Record 7 of Set 3 | evensk
# Processing Record 8 of Set 3 | linxia
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | campohermoso
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | klaksvik
# Processing Record 13 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | bahir dar
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | zunyi
# Processing Record 19 of Set 3 | iznik
# Processing Record 20 of Set 3 | tabukiniberu
# City not found. Skipping...
# Processing Record 21 of Set 3 | cap malheureux
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | dymer
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | cooma
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | batsfjord
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | bathsheba
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 3 | mitu
# Processing Record 34 of Set 3 | morondava
# Processing Record 35 of Set 3 | balakhta
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | tulum
# Processing Record 40 of Set 3 | nikolskoye
# Processing Record 41 of Set 3 | ryotsu
# Processing Record 42 of Set 3 | inhambane
# Processing Record 43 of Set 3 | berbera
# Processing Record 44 of Set 3 | dikson
# Processing Record 45 of Set 3 | nokha
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | verkhnevilyuysk
# Processing Record 48 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 3 | san quintin
# Processing Record 50 of Set 3 | sarankhola
# Processing Record 1 of Set 4 | iqaluit
# Processing Record 2 of Set 4 | hamminkeln
# Processing Record 3 of Set 4 | sola
# Processing Record 4 of Set 4 | kholm-zhirkovskiy
# Processing Record 5 of Set 4 | diffa
# Processing Record 6 of Set 4 | college
# Processing Record 7 of Set 4 | batagay-alyta
# Processing Record 8 of Set 4 | georgiyevka
# Processing Record 9 of Set 4 | skibbereen
# Processing Record 10 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 4 | lebu
# Processing Record 12 of Set 4 | qaanaaq
# Processing Record 13 of Set 4 | leningradskiy
# Processing Record 14 of Set 4 | benguela
# Processing Record 15 of Set 4 | alice springs
# Processing Record 16 of Set 4 | vila
# Processing Record 17 of Set 4 | oranjemund
# Processing Record 18 of Set 4 | makakilo city
# Processing Record 19 of Set 4 | adrar
# Processing Record 20 of Set 4 | portland
# Processing Record 21 of Set 4 | jujuy
# City not found. Skipping...
# Processing Record 22 of Set 4 | luxor
# Processing Record 23 of Set 4 | pisco
# Processing Record 24 of Set 4 | numan
# Processing Record 25 of Set 4 | broken hill
# Processing Record 26 of Set 4 | coruripe
# Processing Record 27 of Set 4 | lagoa
# Processing Record 28 of Set 4 | la ronge
# Processing Record 29 of Set 4 | clyde river
# Processing Record 30 of Set 4 | tuatapere
# Processing Record 31 of Set 4 | eskisehir
# Processing Record 32 of Set 4 | laiagam
# City not found. Skipping...
# Processing Record 33 of Set 4 | viedma
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | margate
# Processing Record 36 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 4 | londrina
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | arman
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 42 of Set 4 | ketchikan
# Processing Record 43 of Set 4 | ayan
# Processing Record 44 of Set 4 | soe
# Processing Record 45 of Set 4 | aklavik
# Processing Record 46 of Set 4 | comodoro rivadavia
# Processing Record 47 of Set 4 | avarua
# Processing Record 48 of Set 4 | valpacos
# Processing Record 49 of Set 4 | loiza
# Processing Record 50 of Set 4 | kapaa
# Processing Record 1 of Set 5 | newport
# Processing Record 2 of Set 5 | bodden town
# Processing Record 3 of Set 5 | sungaipenuh
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | kalabugao
# City not found. Skipping...
# Processing Record 6 of Set 5 | polunochnoye
# Processing Record 7 of Set 5 | shihezi
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | lavrentiya
# Processing Record 10 of Set 5 | lakselv
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | santa maria
# Processing Record 13 of Set 5 | kudahuvadhoo
# Processing Record 14 of Set 5 | maniitsoq
# Processing Record 15 of Set 5 | abu zabad
# Processing Record 16 of Set 5 | north marysville
# City not found. Skipping...
# Processing Record 17 of Set 5 | belmonte
# Processing Record 18 of Set 5 | iquitos
# Processing Record 19 of Set 5 | sitka
# Processing Record 20 of Set 5 | maceio
# Processing Record 21 of Set 5 | noumea
# Processing Record 22 of Set 5 | chunoyar
# Processing Record 23 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 5 | tukrah
# Processing Record 25 of Set 5 | urumqi
# Processing Record 26 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 5 | fonte boa
# Processing Record 28 of Set 5 | road town
# Processing Record 29 of Set 5 | port hedland
# Processing Record 30 of Set 5 | necochea
# Processing Record 31 of Set 5 | torbay
# Processing Record 32 of Set 5 | hovd
# Processing Record 33 of Set 5 | bambous virieux
# Processing Record 34 of Set 5 | sao filipe
# Processing Record 35 of Set 5 | tamandare
# Processing Record 36 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 37 of Set 5 | bocaranga
# City not found. Skipping...
# Processing Record 38 of Set 5 | severo-yeniseyskiy
# Processing Record 39 of Set 5 | lompoc
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | kyzyl-suu
# Processing Record 42 of Set 5 | tessalit
# Processing Record 43 of Set 5 | smolenka
# Processing Record 44 of Set 5 | harper
# Processing Record 45 of Set 5 | aasiaat
# Processing Record 46 of Set 5 | khandbari
# Processing Record 47 of Set 5 | rovaniemi
# Processing Record 48 of Set 5 | dekoa
# City not found. Skipping...
# Processing Record 49 of Set 5 | padang
# Processing Record 50 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 6 | great falls
# Processing Record 2 of Set 6 | khombole
# Processing Record 3 of Set 6 | asfi
# Processing Record 4 of Set 6 | cabinda
# Processing Record 5 of Set 6 | webuye
# Processing Record 6 of Set 6 | amapa
# Processing Record 7 of Set 6 | monticello
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | ouadda
# Processing Record 10 of Set 6 | kahului
# Processing Record 11 of Set 6 | bubaque
# Processing Record 12 of Set 6 | ternate
# Processing Record 13 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 14 of Set 6 | jaca
# Processing Record 15 of Set 6 | ishigaki
# Processing Record 16 of Set 6 | dzaoudzi
# Processing Record 17 of Set 6 | wazzan
# City not found. Skipping...
# Processing Record 18 of Set 6 | gimli
# Processing Record 19 of Set 6 | purpe
# Processing Record 20 of Set 6 | baruun-urt
# Processing Record 21 of Set 6 | durango
# Processing Record 22 of Set 6 | hope
# Processing Record 23 of Set 6 | pangnirtung
# Processing Record 24 of Set 6 | nuuk
# Processing Record 25 of Set 6 | richards bay
# Processing Record 26 of Set 6 | kimbe
# Processing Record 27 of Set 6 | lake city
# Processing Record 28 of Set 6 | muravlenko
# Processing Record 29 of Set 6 | sabla
# Processing Record 30 of Set 6 | nouadhibou
# Processing Record 31 of Set 6 | palmer
# Processing Record 32 of Set 6 | nouakchott
# Processing Record 33 of Set 6 | saint-augustin
# Processing Record 34 of Set 6 | fare
# Processing Record 35 of Set 6 | dimapur
# Processing Record 36 of Set 6 | nishihara
# Processing Record 37 of Set 6 | humaita
# Processing Record 38 of Set 6 | faanui
# Processing Record 39 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 6 | pemangkat
# Processing Record 41 of Set 6 | faya
# Processing Record 42 of Set 6 | kavieng
# Processing Record 43 of Set 6 | coracao de jesus
# Processing Record 44 of Set 6 | visby
# Processing Record 45 of Set 6 | lima
# Processing Record 46 of Set 6 | mustasaari
# Processing Record 47 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 6 | broome
# Processing Record 49 of Set 6 | nizhniy tsasuchey
# Processing Record 50 of Set 6 | camargo
# Processing Record 1 of Set 7 | banjar
# Processing Record 2 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 7 | belfast
# Processing Record 4 of Set 7 | namatanai
# Processing Record 5 of Set 7 | ochakiv
# Processing Record 6 of Set 7 | morro bay
# Processing Record 7 of Set 7 | muzhi
# Processing Record 8 of Set 7 | harrison
# Processing Record 9 of Set 7 | tsabong
# Processing Record 10 of Set 7 | lata
# Processing Record 11 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 7 | te anau
# Processing Record 13 of Set 7 | yarada
# Processing Record 14 of Set 7 | karera
# Processing Record 15 of Set 7 | southbridge
# Processing Record 16 of Set 7 | kaitangata
# Processing Record 17 of Set 7 | rio gallegos
# Processing Record 18 of Set 7 | asau
# Processing Record 19 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 7 | torquay
# Processing Record 21 of Set 7 | prince rupert
# Processing Record 22 of Set 7 | hebi
# Processing Record 23 of Set 7 | hamilton
# Processing Record 24 of Set 7 | north port
# Processing Record 25 of Set 7 | baoning
# Processing Record 26 of Set 7 | kencong
# Processing Record 27 of Set 7 | dzilam gonzalez
# Processing Record 28 of Set 7 | de-kastri
# Processing Record 29 of Set 7 | guatavita
# Processing Record 30 of Set 7 | antalaha
# Processing Record 31 of Set 7 | fort nelson
# Processing Record 32 of Set 7 | saint george
# Processing Record 33 of Set 7 | buraydah
# Processing Record 34 of Set 7 | celestun
# Processing Record 35 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 36 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 7 | coquimbo
# Processing Record 38 of Set 7 | fengzhen
# Processing Record 39 of Set 7 | vila velha
# Processing Record 40 of Set 7 | port keats
# Processing Record 41 of Set 7 | cape canaveral
# Processing Record 42 of Set 7 | abalak
# Processing Record 43 of Set 7 | mercedes
# Processing Record 44 of Set 7 | ornskoldsvik
# Processing Record 45 of Set 7 | moissala
# Processing Record 46 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 7 | otane
# Processing Record 48 of Set 7 | odweyne
# Processing Record 49 of Set 7 | san patricio
# Processing Record 50 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 8 | lithgow
# Processing Record 2 of Set 8 | skjervoy
# Processing Record 3 of Set 8 | lorengau
# Processing Record 4 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 8 | holetown
# Processing Record 6 of Set 8 | bandarbeyla
# Processing Record 7 of Set 8 | samoylovka
# Processing Record 8 of Set 8 | betare oya
# Processing Record 9 of Set 8 | zeya
# Processing Record 10 of Set 8 | tautira
# Processing Record 11 of Set 8 | muriti
# Processing Record 12 of Set 8 | guerrero negro
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | berdigestyakh
# Processing Record 15 of Set 8 | honningsvag
# Processing Record 16 of Set 8 | luang prabang
# Processing Record 17 of Set 8 | helong
# Processing Record 18 of Set 8 | blagoveshchensk
# Processing Record 19 of Set 8 | aketi
# Processing Record 20 of Set 8 | ojhar
# Processing Record 21 of Set 8 | jumla
# Processing Record 22 of Set 8 | amalapuram
# Processing Record 23 of Set 8 | salalah
# Processing Record 24 of Set 8 | boffa
# Processing Record 25 of Set 8 | meadow lake
# Processing Record 26 of Set 8 | jinchang
# Processing Record 27 of Set 8 | husavik
# Processing Record 28 of Set 8 | vanimo
# Processing Record 29 of Set 8 | les cayes
# Processing Record 30 of Set 8 | kununurra
# Processing Record 31 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 32 of Set 8 | tiznit
# Processing Record 33 of Set 8 | marsa matruh
# Processing Record 34 of Set 8 | vao
# Processing Record 35 of Set 8 | emilio carranza
# Processing Record 36 of Set 8 | zambezi
# Processing Record 37 of Set 8 | georgetown
# Processing Record 38 of Set 8 | kuching
# Processing Record 39 of Set 8 | ulyanovo
# City not found. Skipping...
# Processing Record 40 of Set 8 | douentza
# Processing Record 41 of Set 8 | dakar
# Processing Record 42 of Set 8 | puerto del rosario
# Processing Record 43 of Set 8 | santa cruz de la palma
# Processing Record 44 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 8 | gemena
# Processing Record 46 of Set 8 | natal
# Processing Record 47 of Set 8 | tilichiki
# Processing Record 48 of Set 8 | copertino
# Processing Record 49 of Set 8 | pangody
# Processing Record 50 of Set 8 | korem
# Processing Record 1 of Set 9 | kandrian
# Processing Record 2 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 3 of Set 9 | auki
# Processing Record 4 of Set 9 | fernie
# Processing Record 5 of Set 9 | ixtapa
# Processing Record 6 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 7 of Set 9 | jeremie
# Processing Record 8 of Set 9 | camacha
# Processing Record 9 of Set 9 | sabzevar
# Processing Record 10 of Set 9 | pochutla
# Processing Record 11 of Set 9 | taoudenni
# Processing Record 12 of Set 9 | kijang
# Processing Record 13 of Set 9 | wrexham
# Processing Record 14 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 15 of Set 9 | elverum
# Processing Record 16 of Set 9 | bato
# Processing Record 17 of Set 9 | mount gambier
# Processing Record 18 of Set 9 | kamaishi
# Processing Record 19 of Set 9 | cockburn town
# Processing Record 20 of Set 9 | buala
# Processing Record 21 of Set 9 | alindao
# Processing Record 22 of Set 9 | corner brook
# Processing Record 23 of Set 9 | saint anthony
# Processing Record 24 of Set 9 | puquio
# Processing Record 25 of Set 9 | angoche
# Processing Record 26 of Set 9 | jucuaran
# Processing Record 27 of Set 9 | sistranda
# Processing Record 28 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 9 | yelan
# Processing Record 30 of Set 9 | caraquet
# Processing Record 31 of Set 9 | hirara
# Processing Record 32 of Set 9 | udachnyy
# Processing Record 33 of Set 9 | sundumbili
# Processing Record 34 of Set 9 | ploemeur
# Processing Record 35 of Set 9 | maningrida
# Processing Record 36 of Set 9 | bonavista
# Processing Record 37 of Set 9 | kodinar
# Processing Record 38 of Set 9 | chernyshevskiy
# Processing Record 39 of Set 9 | narsaq
# Processing Record 40 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 9 | turayf
# Processing Record 42 of Set 9 | bria
# Processing Record 43 of Set 9 | saurimo
# Processing Record 44 of Set 9 | antofagasta
# Processing Record 45 of Set 9 | qinzhou
# Processing Record 46 of Set 9 | iskateley
# Processing Record 47 of Set 9 | emiliano zapata
# Processing Record 48 of Set 9 | itapetinga
# Processing Record 49 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 9 | vavuniya
# Processing Record 1 of Set 10 | krasnoborsk
# Processing Record 2 of Set 10 | great yarmouth
# Processing Record 3 of Set 10 | atambua
# Processing Record 4 of Set 10 | izhma
# Processing Record 5 of Set 10 | khudumelapye
# Processing Record 6 of Set 10 | biloxi
# Processing Record 7 of Set 10 | mackay
# Processing Record 8 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 10 | troitsk
# Processing Record 10 of Set 10 | chugunash
# City not found. Skipping...
# Processing Record 11 of Set 10 | shieli
# Processing Record 12 of Set 10 | iralaya
# Processing Record 13 of Set 10 | rantepao
# Processing Record 14 of Set 10 | akdepe
# Processing Record 15 of Set 10 | progreso
# Processing Record 16 of Set 10 | skelleftea
# Processing Record 17 of Set 10 | bayir
# Processing Record 18 of Set 10 | lincoln
# Processing Record 19 of Set 10 | rocha
# Processing Record 20 of Set 10 | mauren
# Processing Record 21 of Set 10 | baoqing
# Processing Record 22 of Set 10 | olutanga
# Processing Record 23 of Set 10 | maridi
# Processing Record 24 of Set 10 | grindavik
# Processing Record 25 of Set 10 | geraldton
# Processing Record 26 of Set 10 | venado tuerto
# Processing Record 27 of Set 10 | garowe
# Processing Record 28 of Set 10 | mahajanga
# Processing Record 29 of Set 10 | yeppoon
# Processing Record 30 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 10 | manado
# Processing Record 32 of Set 10 | cabedelo
# Processing Record 33 of Set 10 | leh
# Processing Record 34 of Set 10 | cuitzeo
# Processing Record 35 of Set 10 | mayo
# Processing Record 36 of Set 10 | indramayu
# Processing Record 37 of Set 10 | ritchie
# Processing Record 38 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 10 | devils lake
# Processing Record 40 of Set 10 | lesogorsk
# Processing Record 41 of Set 10 | warrington
# Processing Record 42 of Set 10 | paramonga
# Processing Record 43 of Set 10 | pacific grove
# Processing Record 44 of Set 10 | goderich
# Processing Record 45 of Set 10 | whitefish
# Processing Record 46 of Set 10 | tarko-sale
# Processing Record 47 of Set 10 | dharchula
# Processing Record 48 of Set 10 | pak chong
# Processing Record 49 of Set 10 | banda aceh
# Processing Record 50 of Set 10 | riyadh
# Processing Record 1 of Set 11 | vardo
# Processing Record 2 of Set 11 | sharan
# Processing Record 3 of Set 11 | aksarka
# Processing Record 4 of Set 11 | kulhudhuffushi
# Processing Record 5 of Set 11 | shelburne
# Processing Record 6 of Set 11 | sao jose da coroa grande
# Processing Record 7 of Set 11 | kayiry
# Processing Record 8 of Set 11 | port-cartier
# Processing Record 9 of Set 11 | bismarck
# Processing Record 10 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 11 | kindu
# Processing Record 13 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 14 of Set 11 | kusu
# Processing Record 15 of Set 11 | horstel
# Processing Record 16 of Set 11 | vestmanna
# Processing Record 17 of Set 11 | san buenaventura
# Processing Record 18 of Set 11 | panji
# Processing Record 19 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 20 of Set 11 | kandi
# Processing Record 21 of Set 11 | svetlyy
# Processing Record 22 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 11 | chandia
# Processing Record 24 of Set 11 | hella
# Processing Record 25 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 26 of Set 11 | stende
# Processing Record 27 of Set 11 | burla
# Processing Record 28 of Set 11 | seymchan
# Processing Record 29 of Set 11 | katherine
# Processing Record 30 of Set 11 | solnechnyy
# Processing Record 31 of Set 11 | ambilobe
# Processing Record 32 of Set 11 | labuhan
# Processing Record 33 of Set 11 | wanlaweyn
# Processing Record 34 of Set 11 | portel
# Processing Record 35 of Set 11 | connersville
# Processing Record 36 of Set 11 | mnogovershinnyy
# Processing Record 37 of Set 11 | chicama
# Processing Record 38 of Set 11 | concepcion del uruguay
# Processing Record 39 of Set 11 | kuryk
# Processing Record 40 of Set 11 | ancud
# Processing Record 41 of Set 11 | westport
# Processing Record 42 of Set 11 | platteville
# Processing Record 43 of Set 11 | caxito
# Processing Record 44 of Set 11 | egvekinot
# Processing Record 45 of Set 11 | kingaroy
# Processing Record 46 of Set 11 | the pas
# Processing Record 47 of Set 11 | saint marys
# Processing Record 48 of Set 11 | arica
# Processing Record 49 of Set 11 | phumi samraong
# City not found. Skipping...
# Processing Record 50 of Set 11 | santana do livramento
# Processing Record 1 of Set 12 | murmino
# Processing Record 2 of Set 12 | provideniya
# Processing Record 3 of Set 12 | ponta delgada
# Processing Record 4 of Set 12 | eshowe
# Processing Record 5 of Set 12 | nanortalik
# Processing Record 6 of Set 12 | porto velho
# Processing Record 7 of Set 12 | sur
# Processing Record 8 of Set 12 | burgos
# Processing Record 9 of Set 12 | celendin
# Processing Record 10 of Set 12 | alta floresta
# Processing Record 11 of Set 12 | mehamn
# Processing Record 12 of Set 12 | mutis
# Processing Record 13 of Set 12 | komsomolskiy
# Processing Record 14 of Set 12 | kontagora
# Processing Record 15 of Set 12 | belen
# Processing Record 16 of Set 12 | maloy
# Processing Record 17 of Set 12 | wanaka
# Processing Record 18 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 12 | zyryanka
# Processing Record 20 of Set 12 | darnah
# Processing Record 21 of Set 12 | sao sebastiao
# Processing Record 22 of Set 12 | hauterive
# Processing Record 23 of Set 12 | pastos bons
# Processing Record 24 of Set 12 | biryusinsk
# Processing Record 25 of Set 12 | krasnoarmeysk
# Processing Record 26 of Set 12 | flin flon
# Processing Record 27 of Set 12 | bonfim
# Processing Record 28 of Set 12 | tigil
# Processing Record 29 of Set 12 | scarborough
# Processing Record 30 of Set 12 | stamsund
# City not found. Skipping...
# Processing Record 31 of Set 12 | ukiah
# Processing Record 32 of Set 12 | vostok
# Processing Record 33 of Set 12 | kisangani
# Processing Record 34 of Set 12 | yulara
# Processing Record 35 of Set 12 | picton
# Processing Record 36 of Set 12 | nizhnevartovsk
# Processing Record 37 of Set 12 | filingue
# Processing Record 38 of Set 12 | saint-pierre
# Processing Record 39 of Set 12 | harindanga
# Processing Record 40 of Set 12 | suna
# Processing Record 41 of Set 12 | uddevalla
# Processing Record 42 of Set 12 | sao desiderio
# Processing Record 43 of Set 12 | taltal
# Processing Record 44 of Set 12 | ugoofaaru
# Processing Record 45 of Set 12 | san luis
# Processing Record 46 of Set 12 | kloulklubed
# Processing Record 47 of Set 12 | anamur
# Processing Record 48 of Set 12 | tutoia
# Processing Record 49 of Set 12 | havoysund
# Processing Record 50 of Set 12 | port lincoln
# Processing Record 1 of Set 13 | huarmey
# Processing Record 2 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 13 | sobolevo
# Processing Record 4 of Set 13 | quatre cocos
# Processing Record 5 of Set 13 | andenes
# Processing Record 6 of Set 13 | luanshya
# Processing Record 7 of Set 13 | nikel
# Processing Record 8 of Set 13 | brainerd
# Processing Record 9 of Set 13 | talnakh
# Processing Record 10 of Set 13 | pathanamthitta
# Processing Record 11 of Set 13 | eureka
# Processing Record 12 of Set 13 | praia da vitoria
# Processing Record 13 of Set 13 | mitsamiouli
# Processing Record 14 of Set 13 | najran
# Processing Record 15 of Set 13 | kabinda
# Processing Record 16 of Set 13 | moa
# Processing Record 17 of Set 13 | vila franca do campo
# Processing Record 18 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 19 of Set 13 | iquique
# Processing Record 20 of Set 13 | dehui
# Processing Record 21 of Set 13 | ocos
# Processing Record 22 of Set 13 | yenagoa
# Processing Record 23 of Set 13 | cap-chat
# Processing Record 24 of Set 13 | ranfurly
# Processing Record 25 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 13 | plast
# Processing Record 27 of Set 13 | aksu
# Processing Record 28 of Set 13 | salmo
# Processing Record 29 of Set 13 | hanyang
# Processing Record 30 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 31 of Set 13 | naryan-mar
# Processing Record 32 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 13 | laguna
# Processing Record 34 of Set 13 | jiangyou
# Processing Record 35 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 36 of Set 13 | gumdag
# Processing Record 37 of Set 13 | wewak
# Processing Record 38 of Set 13 | high level
# Processing Record 39 of Set 13 | prado
# Processing Record 40 of Set 13 | paamiut
# Processing Record 41 of Set 13 | sao joao da barra
# Processing Record 42 of Set 13 | nioro
# Processing Record 43 of Set 13 | coos bay
# Processing Record 44 of Set 13 | gari
# Processing Record 45 of Set 13 | capaci
# Processing Record 46 of Set 13 | nyrob
# Processing Record 47 of Set 13 | champerico
# Processing Record 48 of Set 13 | bilgram
# Processing Record 49 of Set 13 | wajir
# Processing Record 50 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 1 of Set 14 | novikovo
# Processing Record 2 of Set 14 | deputatskiy
# Processing Record 3 of Set 14 | damaturu
# Processing Record 4 of Set 14 | luanda
# Processing Record 5 of Set 14 | grand island
# Processing Record 6 of Set 14 | araouane
# Processing Record 7 of Set 14 | tomatlan
# Processing Record 8 of Set 14 | odienne
# Processing Record 9 of Set 14 | binzhou
# Processing Record 10 of Set 14 | vilhena
# Processing Record 11 of Set 14 | san ramon
# Processing Record 12 of Set 14 | birjand
# Processing Record 13 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 14 | ciudad ojeda
# Processing Record 15 of Set 14 | shetpe
# Processing Record 16 of Set 14 | port macquarie
# Processing Record 17 of Set 14 | jizan
# Processing Record 18 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 19 of Set 14 | yatou
# Processing Record 20 of Set 14 | tiarei
# Processing Record 21 of Set 14 | port blair
# Processing Record 22 of Set 14 | varkaus
# Processing Record 23 of Set 14 | elizabeth city
# Processing Record 24 of Set 14 | nyurba
# Processing Record 25 of Set 14 | mul
# Processing Record 26 of Set 14 | arlit
# Processing Record 27 of Set 14 | jamui
# Processing Record 28 of Set 14 | hegang
# Processing Record 29 of Set 14 | susanville
# Processing Record 30 of Set 14 | kangaatsiaq
# Processing Record 31 of Set 14 | chumikan
# Processing Record 32 of Set 14 | tianmen
# Processing Record 33 of Set 14 | aviles
# Processing Record 34 of Set 14 | pankrushikha
# Processing Record 35 of Set 14 | lenger
# Processing Record 36 of Set 14 | luwuk
# Processing Record 37 of Set 14 | kalmunai
# Processing Record 38 of Set 14 | adet
# Processing Record 39 of Set 14 | mancio lima
# Processing Record 40 of Set 14 | turinskaya sloboda
# Processing Record 41 of Set 14 | berlevag
# Processing Record 42 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 14 | waharoa
# Processing Record 44 of Set 14 | hwange
# Processing Record 45 of Set 14 | portales
# Processing Record 46 of Set 14 | piltene
# Processing Record 47 of Set 14 | meulaboh
# Processing Record 48 of Set 14 | fairbanks
# Processing Record 49 of Set 14 | cravo norte
# Processing Record 50 of Set 14 | marsh harbour
# Processing Record 1 of Set 15 | sorland
# Processing Record 2 of Set 15 | churapcha
# Processing Record 3 of Set 15 | uribia
# Processing Record 4 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 5 of Set 15 | flinders
# Processing Record 6 of Set 15 | tari
# Processing Record 7 of Set 15 | hounde
# Processing Record 8 of Set 15 | litovko
# Processing Record 9 of Set 15 | presidencia roque saenz pena
# Processing Record 10 of Set 15 | mantua
# Processing Record 11 of Set 15 | bulgan
# Processing Record 12 of Set 15 | batagay
# Processing Record 13 of Set 15 | de haan
# Processing Record 14 of Set 15 | rancho palos verdes
# Processing Record 15 of Set 15 | marawi
# Processing Record 16 of Set 15 | ahuatempan
# Processing Record 17 of Set 15 | loukhi
# Processing Record 18 of Set 15 | myitkyina
# Processing Record 19 of Set 15 | sioux lookout
# Processing Record 20 of Set 15 | capao bonito
# Processing Record 21 of Set 15 | piro
# Processing Record 22 of Set 15 | grevena
# Processing Record 23 of Set 15 | eyl
# Processing Record 24 of Set 15 | kembe
# Processing Record 25 of Set 15 | sweetwater
# Processing Record 26 of Set 15 | macamic
# Processing Record 27 of Set 15 | santa ana
# Processing Record 28 of Set 15 | yingzhong
# City not found. Skipping...
# Processing Record 29 of Set 15 | sorkjosen
# Processing Record 30 of Set 15 | xam nua
# Processing Record 31 of Set 15 | tandur
# Processing Record 32 of Set 15 | le vauclin
# Processing Record 33 of Set 15 | walvis bay
# Processing Record 34 of Set 15 | simdega
# Processing Record 35 of Set 15 | nioki
# Processing Record 36 of Set 15 | valparaiso
# Processing Record 37 of Set 15 | bairiki
# Processing Record 38 of Set 15 | port hardy
# Processing Record 39 of Set 15 | puerto quijarro
# Processing Record 40 of Set 15 | aksay
# Processing Record 41 of Set 15 | ibra
# Processing Record 42 of Set 15 | ferrol
# Processing Record 43 of Set 15 | dapdap
# Processing Record 44 of Set 15 | tocopilla
# Processing Record 45 of Set 15 | tungor
# Processing Record 46 of Set 15 | qasigiannguit
# Processing Record 47 of Set 15 | buzmeyin
# Processing Record 48 of Set 15 | bilibino
# Processing Record 49 of Set 15 | alyangula
# Processing Record 50 of Set 15 | carikar
# City not found. Skipping...
# Processing Record 1 of Set 16 | shizunai
# Processing Record 2 of Set 16 | douglas
# Processing Record 3 of Set 16 | wadena
# Processing Record 4 of Set 16 | benton harbor
# Processing Record 5 of Set 16 | salisbury
# Processing Record 6 of Set 16 | dhidhdhoo
# Processing Record 7 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 16 | gdansk
# Processing Record 9 of Set 16 | at-bashi
# Processing Record 10 of Set 16 | putineiu
# Processing Record 11 of Set 16 | whitehorse
# Processing Record 12 of Set 16 | talcahuano
# Processing Record 13 of Set 16 | riaba
# City not found. Skipping...
# Processing Record 14 of Set 16 | waddan
# Processing Record 15 of Set 16 | santa cruz del norte
# Processing Record 16 of Set 16 | balkhash
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Touros  -5.1989  -35.4608     86.90        63          83
# 1  Haines Junction  60.7522 -137.5108     35.55        75         100
# 2         Hermanus -34.4187   19.2345     65.89        69          23
# 3          Ushuaia -54.8000  -68.3000     49.66        43           0
# 4        Busselton -33.6500  115.3333     53.10        74          90
# 5       Tolmachevo  54.9824   82.7363     39.42        93          75
# 6            Airai  -8.9266  125.4092     60.24        77          80
# 7        Hithadhoo  -0.6000   73.0833     83.34        75          36
# 8         Maragogi  -9.0122  -35.2225     80.22        71          93
# 9           Bethel  41.3712  -73.4140     73.92        74          40
#
#    Wind Speed Country                 Date Current Description
# 0       17.72      BR  2021-10-07 17:19:42       broken clouds
# 1        3.44      CA  2021-10-07 17:19:44     overcast clouds
# 2        9.04      ZA  2021-10-07 17:19:46          few clouds
# 3        4.61      AR  2021-10-07 17:19:47           clear sky
# 4        9.95      AU  2021-10-07 17:17:11     overcast clouds
# 5       11.18      RU  2021-10-07 17:19:50       broken clouds
# 6        2.35      TL  2021-10-07 17:19:51       broken clouds
# 7       11.54      MV  2021-10-07 17:19:53    scattered clouds
# 8        9.64      BR  2021-10-07 17:19:54     overcast clouds
# 9        4.61      US  2021-10-07 17:19:56    scattered clouds

# %%
# Reorder the columns 
new_column_order = ["City", "Country", "Lat",
                   "Lng", "Max Temp", "Humidity",
                   "Cloudiness", "Wind Speed",
                   "Current Description"]
# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Touros      BR  -5.1989  -35.4608     86.90        63          83
# 1  Haines Junction      CA  60.7522 -137.5108     35.55        75         100
# 2         Hermanus      ZA -34.4187   19.2345     65.89        69          23
# 3          Ushuaia      AR -54.8000  -68.3000     49.66        43           0
# 4        Busselton      AU -33.6500  115.3333     53.10        74          90
# 5       Tolmachevo      RU  54.9824   82.7363     39.42        93          75
# 6            Airai      TL  -8.9266  125.4092     60.24        77          80
# 7        Hithadhoo      MV  -0.6000   73.0833     83.34        75          36
# 8         Maragogi      BR  -9.0122  -35.2225     80.22        71          93
# 9           Bethel      US  41.3712  -73.4140     73.92        74          40
#
#    Wind Speed Current Description
# 0       17.72       broken clouds
# 1        3.44     overcast clouds
# 2        9.04          few clouds
# 3        4.61           clear sky
# 4        9.95     overcast clouds
# 5       11.18       broken clouds
# 6        2.35       broken clouds
# 7       11.54    scattered clouds
# 8        9.64     overcast clouds
# 9        4.61    scattered clouds

# %%
# Export DataFrame as WeatherPy_Database.csv into Weather_Database folder
# create the output file (CSV)
output_data_file = "../Weather_Database/Weather_Database.csv"
# export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
